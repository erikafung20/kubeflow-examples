# %% [markdown]
# <a href="https://colab.research.google.com/github/erikafung20/kubeflow-examples/blob/main/ChatGPT_Clone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create an environment with Python 3.9

# %%
import sys
sys.path.append("/usr/local/lib/python3.9/site-packages")

# %% [markdown]
# The NVIDIA System Management Interface (nvidia-smi) is a command line utility, based on top of the NVIDIA Management Library (NVML), intended to aid in the management and monitoring of NVIDIA GPU devices.

# %%
# !nvidia-smi
# Out:
# Sat Apr  1 06:47:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Download Git Repos

# %%
# !git clone https://github.com/deepanshu88/Alpaca-LoRA-Serve.git
# Out:
# Cloning into 'Alpaca-LoRA-Serve'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 401 (delta 79), reused 94 (delta 60), pack-reused 279
# Receiving objects: 100% (401/401), 116.76 KiB | 2.33 MiB/s, done.
# Resolving deltas: 100% (211/211), done.

# %%
# %cd Alpaca-LoRA-Serve
# Out:
# /content/Alpaca-LoRA-Serve

# %%
# !python3.9 -m pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-4vh8b3iv
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-4vh8b3iv
#   Resolved https://github.com/huggingface/transformers.git to commit c612628045822f909020f7eb6784c79700813eda
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-pu1r5tx4
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-pu1r5tx4
#   Resolved https://github.com/huggingface/peft.git to commit 11edb618c32065083b89918f26ba6f43c4c1804b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %% [markdown]
# # Choose 13B or 7B for free colab version, 30B for premium
#
# Possible values of `--base_url`
#
# - decapoda-research/llama-7b-hf
# - decapoda-research/llama-13b-hf
# - decapoda-research/llama-30b-hf
#
# Possible values of `--ft_ckpt_url`
#
# - tloen/alpaca-lora-7b
# - chansung/alpaca-lora-13b
# - chansung/koalpaca-lora-13b for English to Korean conversations
# - chansung/alpaca-lora-30b

# %%
base_model = 'decapoda-research/llama-7b-hf' #@param ["decapoda-research/llama-7b-hf", "decapoda-research/llama-13b-hf", "decapoda-research/llama-30b-hf"]
finetuned_model = 'tloen/alpaca-lora-7b' #@param ["tloen/alpaca-lora-7b", "chansung/alpaca-lora-13b", "chansung/koalpaca-lora-13b", "chansung/alpaca-lora-30b"]

# %%
# !python3.9 app.py --base_url $base_model --ft_ckpt_url $finetuned_model --share
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ...
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# ...
